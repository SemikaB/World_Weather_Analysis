# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
lats = np.random.uniform(low=-90.000,high=90.000,size=2000)
lngs = np.random.uniform(low=-180.000,high=180.000,size=2000)
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 745

# %%
import requests
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data2 = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_conditions = city_weather["weather"][0]["description"]
        #parsing array reference: https://devqa.io/python-parse-json/
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Append the city information into city_data list.
        city_data2.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                           "Current Description": city_conditions,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | hermanus
# Processing Record 3 of Set 1 | albany
# Processing Record 4 of Set 1 | cap malheureux
# Processing Record 5 of Set 1 | gravdal
# Processing Record 6 of Set 1 | vaini
# Processing Record 7 of Set 1 | hami
# Processing Record 8 of Set 1 | tuatapere
# Processing Record 9 of Set 1 | yambio
# Processing Record 10 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 11 of Set 1 | dalvik
# Processing Record 12 of Set 1 | port elizabeth
# Processing Record 13 of Set 1 | daxian
# City not found. Skipping...
# Processing Record 14 of Set 1 | tessalit
# Processing Record 15 of Set 1 | namibe
# Processing Record 16 of Set 1 | khatanga
# Processing Record 17 of Set 1 | mataura
# Processing Record 18 of Set 1 | imeni poliny osipenko
# Processing Record 19 of Set 1 | dikson
# Processing Record 20 of Set 1 | ulladulla
# Processing Record 21 of Set 1 | palmer
# Processing Record 22 of Set 1 | jamestown
# Processing Record 23 of Set 1 | busselton
# Processing Record 24 of Set 1 | hilo
# Processing Record 25 of Set 1 | kodiak
# Processing Record 26 of Set 1 | punta arenas
# Processing Record 27 of Set 1 | mount gambier
# Processing Record 28 of Set 1 | vardo
# Processing Record 29 of Set 1 | vryburg
# Processing Record 30 of Set 1 | katsuura
# Processing Record 31 of Set 1 | ambilobe
# Processing Record 32 of Set 1 | kavieng
# Processing Record 33 of Set 1 | avarua
# Processing Record 34 of Set 1 | bredasdorp
# Processing Record 35 of Set 1 | barrow
# Processing Record 36 of Set 1 | matiri
# Processing Record 37 of Set 1 | mamallapuram
# Processing Record 38 of Set 1 | kahului
# Processing Record 39 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 40 of Set 1 | klaksvik
# Processing Record 41 of Set 1 | puerto leguizamo
# Processing Record 42 of Set 1 | yar-sale
# Processing Record 43 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 44 of Set 1 | avera
# Processing Record 45 of Set 1 | sao joao da barra
# Processing Record 46 of Set 1 | bluff
# Processing Record 47 of Set 1 | beringovskiy
# Processing Record 48 of Set 1 | thompson
# Processing Record 49 of Set 1 | saskylakh
# Processing Record 50 of Set 1 | saint-philippe
# Processing Record 1 of Set 2 | midyat
# Processing Record 2 of Set 2 | bonthe
# Processing Record 3 of Set 2 | sitka
# Processing Record 4 of Set 2 | iqaluit
# Processing Record 5 of Set 2 | vilhena
# Processing Record 6 of Set 2 | fernie
# Processing Record 7 of Set 2 | butaritari
# Processing Record 8 of Set 2 | boa vista
# Processing Record 9 of Set 2 | georgetown
# Processing Record 10 of Set 2 | batsfjord
# Processing Record 11 of Set 2 | rawannawi
# City not found. Skipping...
# Processing Record 12 of Set 2 | promysla
# City not found. Skipping...
# Processing Record 13 of Set 2 | coffs harbour
# Processing Record 14 of Set 2 | tawkar
# City not found. Skipping...
# Processing Record 15 of Set 2 | chuy
# Processing Record 16 of Set 2 | tefe
# Processing Record 17 of Set 2 | new norfolk
# Processing Record 18 of Set 2 | mocuba
# Processing Record 19 of Set 2 | lewiston
# Processing Record 20 of Set 2 | tiksi
# Processing Record 21 of Set 2 | maningrida
# Processing Record 22 of Set 2 | montepuez
# Processing Record 23 of Set 2 | pozo colorado
# Processing Record 24 of Set 2 | merauke
# Processing Record 25 of Set 2 | slonim
# Processing Record 26 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 27 of Set 2 | padang
# Processing Record 28 of Set 2 | yellowknife
# Processing Record 29 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 30 of Set 2 | bambous virieux
# Processing Record 31 of Set 2 | ribeira grande
# Processing Record 32 of Set 2 | nanortalik
# Processing Record 33 of Set 2 | port-gentil
# Processing Record 34 of Set 2 | imphal
# Processing Record 35 of Set 2 | chumikan
# Processing Record 36 of Set 2 | bethanien
# Processing Record 37 of Set 2 | port alfred
# Processing Record 38 of Set 2 | sosnovo-ozerskoye
# Processing Record 39 of Set 2 | north platte
# Processing Record 40 of Set 2 | taperoa
# Processing Record 41 of Set 2 | rikitea
# Processing Record 42 of Set 2 | arraial do cabo
# Processing Record 43 of Set 2 | la ronge
# Processing Record 44 of Set 2 | hasaki
# Processing Record 45 of Set 2 | puerto varas
# Processing Record 46 of Set 2 | bontang
# Processing Record 47 of Set 2 | muravlenko
# Processing Record 48 of Set 2 | kijang
# Processing Record 49 of Set 2 | impfondo
# Processing Record 50 of Set 2 | rio grande
# Processing Record 1 of Set 3 | kaitangata
# Processing Record 2 of Set 3 | guerrero negro
# Processing Record 3 of Set 3 | bolgatanga
# Processing Record 4 of Set 3 | bethel
# Processing Record 5 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 6 of Set 3 | kumluca
# Processing Record 7 of Set 3 | caravelas
# Processing Record 8 of Set 3 | fairbanks
# Processing Record 9 of Set 3 | aban
# Processing Record 10 of Set 3 | champerico
# Processing Record 11 of Set 3 | ruatoria
# City not found. Skipping...
# Processing Record 12 of Set 3 | puerto ayora
# Processing Record 13 of Set 3 | hobart
# Processing Record 14 of Set 3 | san quintin
# Processing Record 15 of Set 3 | east london
# Processing Record 16 of Set 3 | tura
# Processing Record 17 of Set 3 | taoudenni
# Processing Record 18 of Set 3 | andradina
# Processing Record 19 of Set 3 | viedma
# Processing Record 20 of Set 3 | pangnirtung
# Processing Record 21 of Set 3 | adre
# Processing Record 22 of Set 3 | surt
# Processing Record 23 of Set 3 | taksimo
# Processing Record 24 of Set 3 | sinnamary
# Processing Record 25 of Set 3 | norsup
# Processing Record 26 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 27 of Set 3 | carnarvon
# Processing Record 28 of Set 3 | grand centre
# City not found. Skipping...
# Processing Record 29 of Set 3 | mocambique
# City not found. Skipping...
# Processing Record 30 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 31 of Set 3 | amol
# Processing Record 32 of Set 3 | cape town
# Processing Record 33 of Set 3 | severodvinsk
# Processing Record 34 of Set 3 | wanning
# Processing Record 35 of Set 3 | espanola
# Processing Record 36 of Set 3 | bam
# Processing Record 37 of Set 3 | narsaq
# Processing Record 38 of Set 3 | kieta
# Processing Record 39 of Set 3 | malacatepec
# Processing Record 40 of Set 3 | saint-francois
# Processing Record 41 of Set 3 | sibolga
# Processing Record 42 of Set 3 | qaanaaq
# Processing Record 43 of Set 3 | acari
# Processing Record 44 of Set 3 | san miguel de cauri
# Processing Record 45 of Set 3 | pangkalanbuun
# Processing Record 46 of Set 3 | ternate
# Processing Record 47 of Set 3 | tuktoyaktuk
# Processing Record 48 of Set 3 | rawson
# Processing Record 49 of Set 3 | hervey bay
# Processing Record 50 of Set 3 | nangan
# Processing Record 1 of Set 4 | road town
# Processing Record 2 of Set 4 | novita
# Processing Record 3 of Set 4 | kourou
# Processing Record 4 of Set 4 | alta floresta
# Processing Record 5 of Set 4 | namatanai
# Processing Record 6 of Set 4 | mar del plata
# Processing Record 7 of Set 4 | luwuk
# Processing Record 8 of Set 4 | ciro marina
# Processing Record 9 of Set 4 | northam
# Processing Record 10 of Set 4 | irati
# Processing Record 11 of Set 4 | san carlos de bariloche
# Processing Record 12 of Set 4 | constitucion
# Processing Record 13 of Set 4 | bathsheba
# Processing Record 14 of Set 4 | fort saint john
# City not found. Skipping...
# Processing Record 15 of Set 4 | fortuna
# Processing Record 16 of Set 4 | saint george
# Processing Record 17 of Set 4 | hithadhoo
# Processing Record 18 of Set 4 | pollachi
# Processing Record 19 of Set 4 | gerash
# Processing Record 20 of Set 4 | sao filipe
# Processing Record 21 of Set 4 | opobo
# City not found. Skipping...
# Processing Record 22 of Set 4 | meulaboh
# Processing Record 23 of Set 4 | broken hill
# Processing Record 24 of Set 4 | yarmouth
# Processing Record 25 of Set 4 | lar gerd
# City not found. Skipping...
# Processing Record 26 of Set 4 | evanston
# Processing Record 27 of Set 4 | akdepe
# Processing Record 28 of Set 4 | orlesti
# Processing Record 29 of Set 4 | souillac
# Processing Record 30 of Set 4 | bosobolo
# Processing Record 31 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 32 of Set 4 | adrar
# Processing Record 33 of Set 4 | pacifica
# Processing Record 34 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 35 of Set 4 | torbay
# Processing Record 36 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 37 of Set 4 | nouadhibou
# Processing Record 38 of Set 4 | mount isa
# Processing Record 39 of Set 4 | oistins
# Processing Record 40 of Set 4 | bayanday
# Processing Record 41 of Set 4 | madimba
# Processing Record 42 of Set 4 | cangzhou
# Processing Record 43 of Set 4 | lebu
# Processing Record 44 of Set 4 | kavaratti
# Processing Record 45 of Set 4 | simimbaan
# Processing Record 46 of Set 4 | chokurdakh
# Processing Record 47 of Set 4 | severo-kurilsk
# Processing Record 48 of Set 4 | traganon
# Processing Record 49 of Set 4 | virginia
# Processing Record 50 of Set 4 | naryan-mar
# Processing Record 1 of Set 5 | porto franco
# Processing Record 2 of Set 5 | huilong
# Processing Record 3 of Set 5 | ambovombe
# Processing Record 4 of Set 5 | castro
# Processing Record 5 of Set 5 | atuona
# Processing Record 6 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 7 of Set 5 | esperance
# Processing Record 8 of Set 5 | katrineholm
# Processing Record 9 of Set 5 | bijar
# Processing Record 10 of Set 5 | mountain home
# Processing Record 11 of Set 5 | samarai
# Processing Record 12 of Set 5 | cockburn town
# Processing Record 13 of Set 5 | puerto escondido
# Processing Record 14 of Set 5 | katherine
# Processing Record 15 of Set 5 | hualmay
# Processing Record 16 of Set 5 | srednekolymsk
# Processing Record 17 of Set 5 | touros
# Processing Record 18 of Set 5 | barra do garcas
# Processing Record 19 of Set 5 | kapaa
# Processing Record 20 of Set 5 | hobyo
# Processing Record 21 of Set 5 | san policarpo
# Processing Record 22 of Set 5 | norman wells
# Processing Record 23 of Set 5 | gwanda
# Processing Record 24 of Set 5 | ewo
# Processing Record 25 of Set 5 | luderitz
# Processing Record 26 of Set 5 | saint-augustin
# Processing Record 27 of Set 5 | celestun
# Processing Record 28 of Set 5 | coquimbo
# Processing Record 29 of Set 5 | nikolskoye
# Processing Record 30 of Set 5 | kurilsk
# Processing Record 31 of Set 5 | bengkulu
# Processing Record 32 of Set 5 | henties bay
# Processing Record 33 of Set 5 | ilo
# Processing Record 34 of Set 5 | deshna
# City not found. Skipping...
# Processing Record 35 of Set 5 | campbellsville
# Processing Record 36 of Set 5 | chene-bourg
# Processing Record 37 of Set 5 | pertuis
# Processing Record 38 of Set 5 | hermosillo
# Processing Record 39 of Set 5 | alyangula
# Processing Record 40 of Set 5 | zhob
# Processing Record 41 of Set 5 | talara
# Processing Record 42 of Set 5 | xinyu
# Processing Record 43 of Set 5 | usinsk
# Processing Record 44 of Set 5 | floro
# Processing Record 45 of Set 5 | slave lake
# Processing Record 46 of Set 5 | nador
# Processing Record 47 of Set 5 | naze
# Processing Record 48 of Set 5 | kalininsk
# Processing Record 49 of Set 5 | cidreira
# Processing Record 50 of Set 5 | margate
# Processing Record 1 of Set 6 | lawrenceburg
# Processing Record 2 of Set 6 | orland park
# Processing Record 3 of Set 6 | istanbul
# Processing Record 4 of Set 6 | ambon
# Processing Record 5 of Set 6 | netarhat
# Processing Record 6 of Set 6 | ponta do sol
# Processing Record 7 of Set 6 | kapuskasing
# Processing Record 8 of Set 6 | imbituba
# Processing Record 9 of Set 6 | nioro
# Processing Record 10 of Set 6 | montbrison
# Processing Record 11 of Set 6 | salalah
# Processing Record 12 of Set 6 | koumac
# Processing Record 13 of Set 6 | qandala
# Processing Record 14 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 15 of Set 6 | aykhal
# Processing Record 16 of Set 6 | yangjiang
# Processing Record 17 of Set 6 | talnakh
# Processing Record 18 of Set 6 | tidore
# City not found. Skipping...
# Processing Record 19 of Set 6 | vostok
# Processing Record 20 of Set 6 | fort nelson
# Processing Record 21 of Set 6 | ust-ilimsk
# Processing Record 22 of Set 6 | seoul
# Processing Record 23 of Set 6 | baruun-urt
# Processing Record 24 of Set 6 | lang suan
# Processing Record 25 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 26 of Set 6 | mahebourg
# Processing Record 27 of Set 6 | koygorodok
# Processing Record 28 of Set 6 | igarka
# Processing Record 29 of Set 6 | anloga
# Processing Record 30 of Set 6 | sheregesh
# Processing Record 31 of Set 6 | barbar
# City not found. Skipping...
# Processing Record 32 of Set 6 | jumla
# Processing Record 33 of Set 6 | gorontalo
# Processing Record 34 of Set 6 | clyde river
# Processing Record 35 of Set 6 | kihei
# Processing Record 36 of Set 6 | guarapari
# Processing Record 37 of Set 6 | san patricio
# Processing Record 38 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 39 of Set 6 | tasiilaq
# Processing Record 40 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 41 of Set 6 | balakhta
# Processing Record 42 of Set 6 | tsumeb
# Processing Record 43 of Set 6 | pizarro
# Processing Record 44 of Set 6 | khandyga
# Processing Record 45 of Set 6 | faanui
# Processing Record 46 of Set 6 | airai
# Processing Record 47 of Set 6 | luanda
# Processing Record 48 of Set 6 | emet
# Processing Record 49 of Set 6 | zhigansk
# Processing Record 50 of Set 6 | santa cruz de la palma
# Processing Record 1 of Set 7 | pisco
# Processing Record 2 of Set 7 | acapulco
# Processing Record 3 of Set 7 | sangar
# Processing Record 4 of Set 7 | ca mau
# Processing Record 5 of Set 7 | stettler
# Processing Record 6 of Set 7 | san cristobal
# Processing Record 7 of Set 7 | pangai
# Processing Record 8 of Set 7 | horsens
# Processing Record 9 of Set 7 | sur
# Processing Record 10 of Set 7 | bayan
# Processing Record 11 of Set 7 | verkhoyansk
# Processing Record 12 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 13 of Set 7 | ilulissat
# Processing Record 14 of Set 7 | ifakara
# Processing Record 15 of Set 7 | yeppoon
# Processing Record 16 of Set 7 | yabelo
# Processing Record 17 of Set 7 | coromandel
# Processing Record 18 of Set 7 | ancud
# Processing Record 19 of Set 7 | shitanjing
# Processing Record 20 of Set 7 | mulege
# Processing Record 21 of Set 7 | port washington
# Processing Record 22 of Set 7 | miri
# Processing Record 23 of Set 7 | westport
# Processing Record 24 of Set 7 | durango
# Processing Record 25 of Set 7 | zhuhai
# Processing Record 26 of Set 7 | goderich
# Processing Record 27 of Set 7 | tartagal
# Processing Record 28 of Set 7 | svetlaya
# Processing Record 29 of Set 7 | cayenne
# Processing Record 30 of Set 7 | oktyabrskoye
# Processing Record 31 of Set 7 | cabo san lucas
# Processing Record 32 of Set 7 | lagoa
# Processing Record 33 of Set 7 | datong
# Processing Record 34 of Set 7 | pevek
# Processing Record 35 of Set 7 | shilka
# Processing Record 36 of Set 7 | maldonado
# Processing Record 37 of Set 7 | piacabucu
# Processing Record 38 of Set 7 | kaputa
# Processing Record 39 of Set 7 | urdzhar
# City not found. Skipping...
# Processing Record 40 of Set 7 | emba
# Processing Record 41 of Set 7 | kruisfontein
# Processing Record 42 of Set 7 | provideniya
# Processing Record 43 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 44 of Set 7 | sao felix do xingu
# Processing Record 45 of Set 7 | berezeni
# Processing Record 46 of Set 7 | port-de-paix
# City not found. Skipping...
# Processing Record 47 of Set 7 | ahipara
# Processing Record 48 of Set 7 | finote selam
# Processing Record 49 of Set 7 | longyearbyen
# Processing Record 50 of Set 7 | bosaso
# Processing Record 1 of Set 8 | rudnichnyy
# Processing Record 2 of Set 8 | borbon
# Processing Record 3 of Set 8 | maltahohe
# Processing Record 4 of Set 8 | finschhafen
# Processing Record 5 of Set 8 | sao jose da coroa grande
# Processing Record 6 of Set 8 | hovd
# Processing Record 7 of Set 8 | copiapo
# Processing Record 8 of Set 8 | gornyy
# Processing Record 9 of Set 8 | pajarito
# Processing Record 10 of Set 8 | burnie
# Processing Record 11 of Set 8 | alboraya
# Processing Record 12 of Set 8 | waddan
# Processing Record 13 of Set 8 | port macquarie
# Processing Record 14 of Set 8 | geraldton
# Processing Record 15 of Set 8 | okhotsk
# Processing Record 16 of Set 8 | rocha
# Processing Record 17 of Set 8 | vanavara
# Processing Record 18 of Set 8 | loandjili
# Processing Record 19 of Set 8 | upernavik
# Processing Record 20 of Set 8 | lamesa
# Processing Record 21 of Set 8 | nouna
# Processing Record 22 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 23 of Set 8 | tuggurt
# City not found. Skipping...
# Processing Record 24 of Set 8 | taltal
# Processing Record 25 of Set 8 | flin flon
# Processing Record 26 of Set 8 | panzhihua
# Processing Record 27 of Set 8 | manta
# Processing Record 28 of Set 8 | bonavista
# Processing Record 29 of Set 8 | bandar-e lengeh
# Processing Record 30 of Set 8 | puerto baquerizo moreno
# Processing Record 31 of Set 8 | kenai
# Processing Record 32 of Set 8 | ulaanbaatar
# Processing Record 33 of Set 8 | shimoda
# Processing Record 34 of Set 8 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 35 of Set 8 | the valley
# Processing Record 36 of Set 8 | nizhniy kuranakh
# Processing Record 37 of Set 8 | grenaa
# Processing Record 38 of Set 8 | alofi
# Processing Record 39 of Set 8 | hoima
# Processing Record 40 of Set 8 | dingle
# Processing Record 41 of Set 8 | isangel
# Processing Record 42 of Set 8 | ngukurr
# City not found. Skipping...
# Processing Record 43 of Set 8 | jalu
# Processing Record 44 of Set 8 | sorland
# Processing Record 45 of Set 8 | aksu
# Processing Record 46 of Set 8 | severo-yeniseyskiy
# Processing Record 47 of Set 8 | tucuman
# Processing Record 48 of Set 8 | nishihara
# Processing Record 49 of Set 8 | sechura
# Processing Record 50 of Set 8 | toftir
# City not found. Skipping...
# Processing Record 1 of Set 9 | raudeberg
# Processing Record 2 of Set 9 | hambantota
# Processing Record 3 of Set 9 | alpena
# Processing Record 4 of Set 9 | kushima
# Processing Record 5 of Set 9 | jian
# Processing Record 6 of Set 9 | kedrovyy
# Processing Record 7 of Set 9 | araouane
# Processing Record 8 of Set 9 | forssa
# Processing Record 9 of Set 9 | hamilton
# Processing Record 10 of Set 9 | umm lajj
# Processing Record 11 of Set 9 | khasan
# Processing Record 12 of Set 9 | qaqortoq
# Processing Record 13 of Set 9 | urumqi
# Processing Record 14 of Set 9 | bandarbeyla
# Processing Record 15 of Set 9 | nenjiang
# Processing Record 16 of Set 9 | kamina
# Processing Record 17 of Set 9 | disna
# Processing Record 18 of Set 9 | xuanwu
# Processing Record 19 of Set 9 | pitsunda
# Processing Record 20 of Set 9 | codrington
# Processing Record 21 of Set 9 | arkhangelsk
# Processing Record 22 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 23 of Set 9 | ponta delgada
# Processing Record 24 of Set 9 | isfana
# Processing Record 25 of Set 9 | mahina
# Processing Record 26 of Set 9 | sungaipenuh
# Processing Record 27 of Set 9 | college
# Processing Record 28 of Set 9 | victoria
# Processing Record 29 of Set 9 | ballina
# Processing Record 30 of Set 9 | kiunga
# Processing Record 31 of Set 9 | fare
# Processing Record 32 of Set 9 | hit
# Processing Record 33 of Set 9 | una
# Processing Record 34 of Set 9 | egvekinot
# Processing Record 35 of Set 9 | kloulklubed
# Processing Record 36 of Set 9 | golden
# Processing Record 37 of Set 9 | cabedelo
# Processing Record 38 of Set 9 | othaya
# Processing Record 39 of Set 9 | boralday
# Processing Record 40 of Set 9 | chincha alta
# Processing Record 41 of Set 9 | wencheng
# Processing Record 42 of Set 9 | husavik
# Processing Record 43 of Set 9 | mnogovershinnyy
# Processing Record 44 of Set 9 | savinskiy
# Processing Record 45 of Set 9 | ust-kuyga
# Processing Record 46 of Set 9 | sayyan
# Processing Record 47 of Set 9 | saldanha
# Processing Record 48 of Set 9 | syamzha
# Processing Record 49 of Set 9 | ostrovnoy
# Processing Record 50 of Set 9 | nanakuli
# Processing Record 1 of Set 10 | akcakoca
# Processing Record 2 of Set 10 | pinheiro machado
# Processing Record 3 of Set 10 | waitara
# Processing Record 4 of Set 10 | praia da vitoria
# Processing Record 5 of Set 10 | gangotri
# City not found. Skipping...
# Processing Record 6 of Set 10 | quatre cocos
# Processing Record 7 of Set 10 | quelimane
# Processing Record 8 of Set 10 | cap-aux-meules
# Processing Record 9 of Set 10 | porbandar
# Processing Record 10 of Set 10 | sakakah
# Processing Record 11 of Set 10 | port hardy
# Processing Record 12 of Set 10 | lata
# Processing Record 13 of Set 10 | mahibadhoo
# Processing Record 14 of Set 10 | labytnangi
# Processing Record 15 of Set 10 | gizo
# Processing Record 16 of Set 10 | ahuimanu
# Processing Record 17 of Set 10 | sambava
# Processing Record 18 of Set 10 | gat
# Processing Record 19 of Set 10 | jomalig
# City not found. Skipping...
# Processing Record 20 of Set 10 | eureka
# Processing Record 21 of Set 10 | sulangan
# Processing Record 22 of Set 10 | iaciara
# Processing Record 23 of Set 10 | xining
# Processing Record 24 of Set 10 | buala
# Processing Record 25 of Set 10 | jalingo
# Processing Record 26 of Set 10 | mayna
# Processing Record 27 of Set 10 | tateyama
# Processing Record 28 of Set 10 | lida
# Processing Record 29 of Set 10 | kaoma
# Processing Record 30 of Set 10 | cherskiy
# Processing Record 31 of Set 10 | kholodnyy
# Processing Record 32 of Set 10 | fallon
# Processing Record 33 of Set 10 | mapastepec
# Processing Record 34 of Set 10 | ugoofaaru
# Processing Record 35 of Set 10 | oromocto
# Processing Record 36 of Set 10 | prnjavor
# Processing Record 37 of Set 10 | siavonga
# Processing Record 38 of Set 10 | belmonte
# Processing Record 39 of Set 10 | otuzco
# Processing Record 40 of Set 10 | lavrentiya
# Processing Record 41 of Set 10 | marsabit
# Processing Record 42 of Set 10 | maputo
# Processing Record 43 of Set 10 | cerro grande
# Processing Record 44 of Set 10 | korla
# Processing Record 45 of Set 10 | yulara
# Processing Record 46 of Set 10 | safaqis
# City not found. Skipping...
# Processing Record 47 of Set 10 | coihueco
# Processing Record 48 of Set 10 | eyl
# Processing Record 49 of Set 10 | stokmarknes
# Processing Record 50 of Set 10 | xuanzhou
# Processing Record 1 of Set 11 | grindavik
# Processing Record 2 of Set 11 | oranjestad
# Processing Record 3 of Set 11 | omboue
# Processing Record 4 of Set 11 | moose factory
# Processing Record 5 of Set 11 | ankazobe
# Processing Record 6 of Set 11 | kemin
# Processing Record 7 of Set 11 | dicabisagan
# Processing Record 8 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 9 of Set 11 | xichang
# Processing Record 10 of Set 11 | dibaya
# City not found. Skipping...
# Processing Record 11 of Set 11 | mzimba
# Processing Record 12 of Set 11 | pokosnoye
# Processing Record 13 of Set 11 | farafangana
# Processing Record 14 of Set 11 | danville
# Processing Record 15 of Set 11 | kargil
# Processing Record 16 of Set 11 | irsha
# Processing Record 17 of Set 11 | athabasca
# Processing Record 18 of Set 11 | ewa beach
# Processing Record 19 of Set 11 | lethem
# Processing Record 20 of Set 11 | birobidzhan
# Processing Record 21 of Set 11 | arlit
# Processing Record 22 of Set 11 | nuuk
# Processing Record 23 of Set 11 | dukat
# Processing Record 24 of Set 11 | sukhoverkovo
# City not found. Skipping...
# Processing Record 25 of Set 11 | upington
# Processing Record 26 of Set 11 | derzhavinsk
# Processing Record 27 of Set 11 | tual
# Processing Record 28 of Set 11 | walvis bay
# Processing Record 29 of Set 11 | domoni
# Processing Record 30 of Set 11 | am timan
# Processing Record 31 of Set 11 | sabang
# Processing Record 32 of Set 11 | chadiza
# Processing Record 33 of Set 11 | ola
# Processing Record 34 of Set 11 | dhanwar
# Processing Record 35 of Set 11 | shache
# Processing Record 36 of Set 11 | mehamn
# Processing Record 37 of Set 11 | qingdao
# Processing Record 38 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 39 of Set 11 | saint-georges
# Processing Record 40 of Set 11 | nome
# Processing Record 41 of Set 11 | pitimbu
# Processing Record 42 of Set 11 | maniitsoq
# Processing Record 43 of Set 11 | vuktyl
# Processing Record 44 of Set 11 | paita
# Processing Record 45 of Set 11 | necochea
# Processing Record 46 of Set 11 | vestmannaeyjar
# Processing Record 47 of Set 11 | high level
# Processing Record 48 of Set 11 | belorechensk
# Processing Record 49 of Set 11 | vao
# Processing Record 50 of Set 11 | harper
# Processing Record 1 of Set 12 | ferreira do alentejo
# Processing Record 2 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 3 of Set 12 | tabas
# Processing Record 4 of Set 12 | dwarka
# Processing Record 5 of Set 12 | ariquemes
# Processing Record 6 of Set 12 | letlhakeng
# Processing Record 7 of Set 12 | perth
# Processing Record 8 of Set 12 | sarankhola
# Processing Record 9 of Set 12 | pedregulho
# Processing Record 10 of Set 12 | nivala
# Processing Record 11 of Set 12 | moron
# Processing Record 12 of Set 12 | tucumcari
# Processing Record 13 of Set 12 | ayan
# Processing Record 14 of Set 12 | cotonou
# Processing Record 15 of Set 12 | kushiro
# Processing Record 16 of Set 12 | singkawang
# Processing Record 17 of Set 12 | torata
# Processing Record 18 of Set 12 | conde
# Processing Record 19 of Set 12 | nemuro
# Processing Record 20 of Set 12 | aswan
# Processing Record 21 of Set 12 | tabou
# Processing Record 22 of Set 12 | lander
# Processing Record 23 of Set 12 | iquique
# Processing Record 24 of Set 12 | atherton
# Processing Record 25 of Set 12 | okha
# Processing Record 26 of Set 12 | kargasok
# Processing Record 27 of Set 12 | aklavik
# Processing Record 28 of Set 12 | lhokseumawe
# Processing Record 29 of Set 12 | hay river
# Processing Record 30 of Set 12 | tres arroyos
# Processing Record 31 of Set 12 | aginskoye
# Processing Record 32 of Set 12 | tilichiki
# Processing Record 33 of Set 12 | taylorville
# Processing Record 34 of Set 12 | watertown
# Processing Record 35 of Set 12 | uglich
# Processing Record 36 of Set 12 | zhaotong
# Processing Record 37 of Set 12 | gniezno
# Processing Record 38 of Set 12 | kerema
# Processing Record 39 of Set 12 | brae
# Processing Record 40 of Set 12 | vila velha
# Processing Record 41 of Set 12 | asau
# Processing Record 42 of Set 12 | hirara
# Processing Record 43 of Set 12 | campbell river
# Processing Record 44 of Set 12 | picos
# Processing Record 45 of Set 12 | launceston
# Processing Record 46 of Set 12 | zeya
# Processing Record 47 of Set 12 | buin
# Processing Record 48 of Set 12 | sibu
# Processing Record 49 of Set 12 | malakal
# Processing Record 50 of Set 12 | ayutthaya
# Processing Record 1 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 2 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 3 of Set 13 | nordfjordeid
# Processing Record 4 of Set 13 | kerouane
# Processing Record 5 of Set 13 | kletskaya
# Processing Record 6 of Set 13 | port blair
# Processing Record 7 of Set 13 | anadyr
# Processing Record 8 of Set 13 | nioki
# Processing Record 9 of Set 13 | barahona
# Processing Record 10 of Set 13 | arrecife
# Processing Record 11 of Set 13 | sisimiut
# Processing Record 12 of Set 13 | fuling
# Processing Record 13 of Set 13 | tubmanburg
# Processing Record 14 of Set 13 | dondo
# Processing Record 15 of Set 13 | tautira
# Processing Record 16 of Set 13 | tiznit
# Processing Record 17 of Set 13 | virginia beach
# Processing Record 18 of Set 13 | bud
# Processing Record 19 of Set 13 | port-cartier
# Processing Record 20 of Set 13 | nevesinje
# Processing Record 21 of Set 13 | salgar
# Processing Record 22 of Set 13 | aybak
# City not found. Skipping...
# Processing Record 23 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 24 of Set 13 | houston
# Processing Record 25 of Set 13 | berwick
# Processing Record 26 of Set 13 | bengkalis
# City not found. Skipping...
# Processing Record 27 of Set 13 | teguise
# Processing Record 28 of Set 13 | mayma
# Processing Record 29 of Set 13 | tsushima
# Processing Record 30 of Set 13 | manado
# Processing Record 31 of Set 13 | lima
# Processing Record 32 of Set 13 | escanaba
# Processing Record 33 of Set 13 | bereda
# Processing Record 34 of Set 13 | pochutla
# Processing Record 35 of Set 13 | jega
# Processing Record 36 of Set 13 | buraydah
# Processing Record 37 of Set 13 | kutum
# Processing Record 38 of Set 13 | maloy
# Processing Record 39 of Set 13 | verkhnyaya toyma
# Processing Record 40 of Set 13 | jacareacanga
# Processing Record 41 of Set 13 | murupara
# Processing Record 42 of Set 13 | gao
# Processing Record 43 of Set 13 | santa maria
# Processing Record 44 of Set 13 | popondetta
# Processing Record 45 of Set 13 | lorengau
# Processing Record 46 of Set 13 | belaya gora
# Processing Record 47 of Set 13 | batagay-alyta
# Processing Record 48 of Set 13 | takoradi
# Processing Record 49 of Set 13 | yaransk
# Processing Record 50 of Set 13 | los llanos de aridane
# Processing Record 1 of Set 14 | soloneshnoye
# Processing Record 2 of Set 14 | iranshahr
# Processing Record 3 of Set 14 | camacha
# Processing Record 4 of Set 14 | warmbad
# Processing Record 5 of Set 14 | puno
# Processing Record 6 of Set 14 | mitsamiouli
# Processing Record 7 of Set 14 | mixtepec
# City not found. Skipping...
# Processing Record 8 of Set 14 | novaya ladoga
# Processing Record 9 of Set 14 | pacific grove
# Processing Record 10 of Set 14 | mandalgovi
# Processing Record 11 of Set 14 | muros
# Processing Record 12 of Set 14 | alekseyevsk
# Processing Record 13 of Set 14 | turukhansk
# Processing Record 14 of Set 14 | oreanda
# City not found. Skipping...
# Processing Record 15 of Set 14 | meadow lake
# Processing Record 16 of Set 14 | honiara
# Processing Record 17 of Set 14 | praya
# Processing Record 18 of Set 14 | hofn
# Processing Record 19 of Set 14 | boyolangu
# Processing Record 20 of Set 14 | xiaoshi
# Processing Record 21 of Set 14 | haines junction
# Processing Record 22 of Set 14 | catabola
# Processing Record 23 of Set 14 | monteiro
# Processing Record 24 of Set 14 | whitehorse
# Processing Record 25 of Set 14 | belyy yar
# Processing Record 26 of Set 14 | touba
# Processing Record 27 of Set 14 | poum
# Processing Record 28 of Set 14 | san jose
# Processing Record 29 of Set 14 | kovdor
# Processing Record 30 of Set 14 | shellbrook
# Processing Record 31 of Set 14 | brownsville
# Processing Record 32 of Set 14 | morondava
# Processing Record 33 of Set 14 | xiangxiang
# Processing Record 34 of Set 14 | dzhebariki-khaya
# Processing Record 35 of Set 14 | lukovetskiy
# Processing Record 36 of Set 14 | gympie
# Processing Record 37 of Set 14 | portland
# Processing Record 38 of Set 14 | stornoway
# Processing Record 39 of Set 14 | toba
# Processing Record 40 of Set 14 | nogliki
# Processing Record 41 of Set 14 | santa cruz cabralia
# Processing Record 42 of Set 14 | ciudad bolivar
# Processing Record 43 of Set 14 | casteltermini
# Processing Record 44 of Set 14 | uige
# Processing Record 45 of Set 14 | beloha
# Processing Record 46 of Set 14 | voi
# Processing Record 47 of Set 14 | scarborough
# Processing Record 48 of Set 14 | vikhorevka
# Processing Record 49 of Set 14 | ixtapa
# Processing Record 50 of Set 14 | muswellbrook
# Processing Record 1 of Set 15 | surgut
# Processing Record 2 of Set 15 | alice springs
# Processing Record 3 of Set 15 | aksha
# Processing Record 4 of Set 15 | banyo
# Processing Record 5 of Set 15 | huarmey
# Processing Record 6 of Set 15 | dunedin
# Processing Record 7 of Set 15 | sawtell
# Processing Record 8 of Set 15 | sistranda
# Processing Record 9 of Set 15 | biryusinsk
# Processing Record 10 of Set 15 | shingu
# Processing Record 11 of Set 15 | oulainen
# Processing Record 12 of Set 15 | kepno
# Processing Record 13 of Set 15 | debre birhan
# Processing Record 14 of Set 15 | burica
# City not found. Skipping...
# Processing Record 15 of Set 15 | boysun
# Processing Record 16 of Set 15 | tongzi
# Processing Record 17 of Set 15 | upala
# Processing Record 18 of Set 15 | cayambe
# Processing Record 19 of Set 15 | kadykchan
# City not found. Skipping...
# Processing Record 20 of Set 15 | himora
# City not found. Skipping...
# Processing Record 21 of Set 15 | lubyany
# Processing Record 22 of Set 15 | plover
# Processing Record 23 of Set 15 | solnechnyy
# Processing Record 24 of Set 15 | coihaique
# Processing Record 25 of Set 15 | chimbote
# Processing Record 26 of Set 15 | abu jubayhah
# City not found. Skipping...
# Processing Record 27 of Set 15 | xiaoweizhai
# Processing Record 28 of Set 15 | praia
# Processing Record 29 of Set 15 | fort-shevchenko
# Processing Record 30 of Set 15 | yuli
# Processing Record 31 of Set 15 | balykshi
# Processing Record 32 of Set 15 | chara
# Processing Record 33 of Set 15 | princeton
# Processing Record 34 of Set 15 | khani
# Processing Record 35 of Set 15 | acheng
# Processing Record 36 of Set 15 | port keats
# Processing Record 37 of Set 15 | methoni
# Processing Record 38 of Set 15 | carutapera
# Processing Record 39 of Set 15 | vanimo
# Processing Record 40 of Set 15 | zlobin
# Processing Record 41 of Set 15 | gummidipundi
# Processing Record 42 of Set 15 | neuquen
# Processing Record 43 of Set 15 | marzuq
# Processing Record 44 of Set 15 | borba
# Processing Record 45 of Set 15 | clinton
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
print(len(city_data2))
# Out:
# 687

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_sub_df = pd.DataFrame(city_data2)
city_data_sub_df.head(10)
# Out:
#              City      Lat       Lng Current Description  Max Temp  Humidity  \
# 0         Ushuaia -54.8000  -68.3000    scattered clouds     42.46        75
# 1        Hermanus -34.4187   19.2345     overcast clouds     58.42        64
# 2          Albany  42.6001  -73.9662     overcast clouds     53.38        36
# 3  Cap Malheureux -19.9842   57.6142       broken clouds     74.46        71
# 4         Gravdal  68.1214   13.5031     overcast clouds     40.89        89
# 5           Vaini -21.2000 -175.2000    scattered clouds     80.76        74
# 6            Hami  42.8000   93.4500    scattered clouds     63.73        23
# 7       Tuatapere -46.1333  167.6833     overcast clouds     50.36        83
# 8          Yambio   4.5721   28.3955    scattered clouds     69.85        87
# 9          Dalvik  65.9702  -18.5286       broken clouds     35.53        73
#
#    Cloudiness  Wind Speed Country
# 0          40       12.66      AR
# 1         100        4.12      ZA
# 2         100        4.36      US
# 3          66        5.01      MU
# 4          94        8.39      NO
# 5          40        3.44      TO
# 6          41        8.99      CN
# 7         100       13.24      NZ
# 8          31        3.27      SS
# 9          65        2.82      IS

# %%
new_column_order=["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]
city_data_sub_df = city_data_sub_df[new_column_order]
city_data_sub_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Ushuaia      AR -54.8000  -68.3000     42.46        75          40
# 1        Hermanus      ZA -34.4187   19.2345     58.42        64         100
# 2          Albany      US  42.6001  -73.9662     53.38        36         100
# 3  Cap Malheureux      MU -19.9842   57.6142     74.46        71          66
# 4         Gravdal      NO  68.1214   13.5031     40.89        89          94
# 5           Vaini      TO -21.2000 -175.2000     80.76        74          40
# 6            Hami      CN  42.8000   93.4500     63.73        23          41
# 7       Tuatapere      NZ -46.1333  167.6833     50.36        83         100
# 8          Yambio      SS   4.5721   28.3955     69.85        87          31
# 9          Dalvik      IS  65.9702  -18.5286     35.53        73          65
#
#    Wind Speed Current Description
# 0       12.66    scattered clouds
# 1        4.12     overcast clouds
# 2        4.36     overcast clouds
# 3        5.01       broken clouds
# 4        8.39     overcast clouds
# 5        3.44    scattered clouds
# 6        8.99    scattered clouds
# 7       13.24     overcast clouds
# 8        3.27    scattered clouds
# 9        2.82       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_sub_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]
